# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import warnings
warnings.filterwarnings('ignore')

# %%
global_terrorist = pd.read_csv('datasets//Global_terrorist.csv', encoding='ISO-8859-1')

# %%
global_terrorist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
global_terrorist.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# <h1>Filtering</h1>

# %%
global_terrorist['iyear'].value_counts().head(5)
# Out:
# iyear
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# Name: count, dtype: int64

# %%
global_terrorist['region_txt'].value_counts().head(5)
# Out:
# region_txt
# Middle East & North Africa    50474
# South Asia                    44974
# South America                 18978
# Sub-Saharan Africa            17550
# Western Europe                16639
# Name: count, dtype: int64

# %%
global_terrorist['attacktype1_txt'].value_counts()
# Out:
# attacktype1_txt
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: count, dtype: int64

# %%
global_terrorist['targtype1_txt'].value_counts().head(5)
# Out:
# targtype1_txt
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: count, dtype: int64

# %%
global_terrorist['weaptype1_txt'].value_counts()
# Out:
# weaptype1_txt
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      14
# Name: count, dtype: int64

# %%
global_terrorist['weapsubtype1_txt'].value_counts().head(5)
# Out:
# weapsubtype1_txt
# Unknown Explosive Type                       44980
# Unknown Gun Type                             33137
# Automatic or Semi-Automatic Rifle            17412
# Vehicle                                       9900
# Projectile (rockets, mortars, RPGs, etc.)     9848
# Name: count, dtype: int64

# %% [markdown]
# <h1>Insights from Conflict: Analyzing the Aftermath of the Terrorist Attacks In the Philippines (personal investigation)</h1>

# %% [markdown]
# # Marawi Siege

# %%
filter1 = global_terrorist[global_terrorist['iyear'] == 2017]

# %%
# filter2 = filter1[filter1['country_txt'] == 'Philippines']

# %%
filter2 = filter1[filter1['country_txt'] == 'Philippines']

# %%
filter3 = filter2[(filter2['imonth'] >= 5) & (filter2['imonth'] <= 10)]

# %%
filter4 = filter3[filter3['city'] == 'Marawi']

# %%
# filter4[filter4['attacktype1_txt'] == 'Bombing/Explosion'].count()

# %%
filter5 = filter4[filter4['attacktype1_txt'] == 'Hostage Taking (Kidnapping)']
# filter4['attacktype1_txt'].value_counts()

# %%
filter5_v2 = filter4[filter4['attacktype1_txt'] == 'Bombing/Explosion']

# %%
filter4['targtype1_txt'].value_counts()
# Out:
# targtype1_txt
# Military                          8
# Private Citizens & Property       4
# Police                            3
# Business                          1
# Educational Institution           1
# Religious Figures/Institutions    1
# Other                             1
# Name: count, dtype: int64

# %%
filter5_v3 = filter4[filter4['targtype1_txt'] == 'Military']

# %% [markdown]
# <h1>Heat Map hostage Taking on Marawi Siege</h1>

# %%
coordinates = filter5.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
Hostagetaking = folium.Map(location = [8, 124.3], zoom_start = 15)
HeatMap(heatmap_data).add_to(Hostagetaking)
Hostagetaking.save('terrorism_Hostagetaking.html')
Hostagetaking
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_195c25ebff99d2d85d26da619d560050 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_195c25ebff99d2d85d26da619d560050&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_195c25ebff99d2d85d26da619d560050 = L.map(
#                 &quot;map_195c25ebff99d2d85d26da619d560050&quot;,
#                 {
#                     center: [8.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a656fce53363ec5b26b94d4234fc7031 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a656fce53363ec5b26b94d4234fc7031.addTo(map_195c25ebff99d2d85d26da619d560050);
#
#
#             var heat_map_b5169296179ae5e4cdfef98e51bfa043 = L.heatLayer(
#                 [[8.000721, 124.293111, 1.0], [8.001314, 124.293493, 1.0], [8.005161, 124.287527, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_b5169296179ae5e4cdfef98e51bfa043.addTo(map_195c25ebff99d2d85d26da619d560050);
#
#
#             tile_layer_a656fce53363ec5b26b94d4234fc7031.addTo(map_195c25ebff99d2d85d26da619d560050);
#
#
#             heat_map_b5169296179ae5e4cdfef98e51bfa043.addTo(map_195c25ebff99d2d85d26da619d560050);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h1>Heat Map on Bombing and Explosion on Marawi Seige</h1>

# %%
coordinates = filter5_v2.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
BombingExplosion = folium.Map(location = [8, 124.3], zoom_start = 15)
HeatMap(heatmap_data).add_to(BombingExplosion)
BombingExplosion.save('terrorism_bombing.html')
BombingExplosion
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6ac995dd13c8c8ebb4443c7b645b9b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6ac995dd13c8c8ebb4443c7b645b9b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6ac995dd13c8c8ebb4443c7b645b9b2 = L.map(
#                 &quot;map_f6ac995dd13c8c8ebb4443c7b645b9b2&quot;,
#                 {
#                     center: [8.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f629f2ff87094f4aeab369e91b94f20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f629f2ff87094f4aeab369e91b94f20.addTo(map_f6ac995dd13c8c8ebb4443c7b645b9b2);
#
#
#             var heat_map_57cc4cf69f754e47c306b9e645a300fc = L.heatLayer(
#                 [[7.999799, 124.300068, 1.0], [7.999981, 124.299937, 1.0], [8.000147, 124.299951, 3.0], [8.000178, 124.300179, 2.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_57cc4cf69f754e47c306b9e645a300fc.addTo(map_f6ac995dd13c8c8ebb4443c7b645b9b2);
#
#
#             tile_layer_8f629f2ff87094f4aeab369e91b94f20.addTo(map_f6ac995dd13c8c8ebb4443c7b645b9b2);
#
#
#             heat_map_57cc4cf69f754e47c306b9e645a300fc.addTo(map_f6ac995dd13c8c8ebb4443c7b645b9b2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coordinates = filter5_v3.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
targtype = folium.Map(location = [8, 124.3], zoom_start = 15)
HeatMap(heatmap_data).add_to(targtype)
targtype.save('terrorism_targtype.html')
targtype
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ede90ddaa340c2fb1bb2dac63d349b3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ede90ddaa340c2fb1bb2dac63d349b3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ede90ddaa340c2fb1bb2dac63d349b3b = L.map(
#                 &quot;map_ede90ddaa340c2fb1bb2dac63d349b3b&quot;,
#                 {
#                     center: [8.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4babdd8457a0988de5518ec77d8e558 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4babdd8457a0988de5518ec77d8e558.addTo(map_ede90ddaa340c2fb1bb2dac63d349b3b);
#
#
#             var heat_map_970d35e46ffe022c53c8cb333c811bdd = L.heatLayer(
#                 [[7.999799, 124.300068, 2.0], [7.999981, 124.299937, 1.0], [8.000147, 124.299951, 3.0], [8.000178, 124.300179, 2.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_970d35e46ffe022c53c8cb333c811bdd.addTo(map_ede90ddaa340c2fb1bb2dac63d349b3b);
#
#
#             tile_layer_e4babdd8457a0988de5518ec77d8e558.addTo(map_ede90ddaa340c2fb1bb2dac63d349b3b);
#
#
#             heat_map_970d35e46ffe022c53c8cb333c811bdd.addTo(map_ede90ddaa340c2fb1bb2dac63d349b3b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # MILF Attacks 1990s to 2000s

# %%
MILF_filter1 = global_terrorist[(global_terrorist['iyear'] >= 1990) & (global_terrorist['iyear'] <= 2000)]

# %%
MILF_filter2 = MILF_filter1[MILF_filter1['country_txt'] == 'Philippines']

# %% [markdown]
# # Mapping the Frequency of MILF-Linked Incidents in the Philippines (1990–2000)

# %%
MILF_filter3 = MILF_filter2[MILF_filter2['gname'] == 'Moro Islamic Liberation Front (MILF)']

# %%
coordinates = MILF_filter3.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
MILF_incidents = folium.Map(location = [12, 124.3], zoom_start =5.5)
HeatMap(heatmap_data).add_to(MILF_incidents)
MILF_incidents.save('terrorism_MILF_incidents.html')
MILF_incidents
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33fd662c1b0d5752e7eea0f207eb56db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33fd662c1b0d5752e7eea0f207eb56db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33fd662c1b0d5752e7eea0f207eb56db = L.map(
#                 &quot;map_33fd662c1b0d5752e7eea0f207eb56db&quot;,
#                 {
#                     center: [12.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc2355d20057324dd2813aa41a36de07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc2355d20057324dd2813aa41a36de07.addTo(map_33fd662c1b0d5752e7eea0f207eb56db);
#
#
#             var heat_map_afb7022515b8ac9857c09fca74f9844a = L.heatLayer(
#                 [[5.864184, 124.996176, 1.0], [6.11622, 125.169395, 8.0], [6.382298, 124.898278, 1.0], [6.420622, 121.973513, 1.0], [6.497216, 122.105141, 1.0], [6.497656, 124.849655, 1.0], [6.508416, 124.855245, 1.0], [6.630015, 122.111817, 1.0], [6.634938, 124.598033, 1.0], [6.641574, 122.157351, 1.0], [6.681959, 121.985477, 4.0], [6.804105, 124.634045, 1.0], [6.828821, 124.893574, 1.0], [6.868645, 124.441079, 2.0], [6.892857, 124.6218, 3.0], [6.935982, 124.450421, 1.0], [6.949288, 124.884481, 2.0], [7.01061, 125.091134, 1.0], [7.017022, 124.893526, 1.0], [7.020898, 125.091469, 3.0], [7.057424, 124.678935, 1.0], [7.086218, 124.901921, 2.0], [7.087719, 124.900522, 1.0], [7.108994, 124.826812, 1.0], [7.109883, 124.824303, 3.0], [7.111828, 124.824596, 1.0], [7.115391, 124.836625, 2.0], [7.117876, 124.38499, 1.0], [7.118334, 124.817434, 1.0], [7.159092, 124.576538, 1.0], [7.189585, 124.534397, 1.0], [7.199509, 124.796982, 5.0], [7.204961, 124.791148, 1.0], [7.209594, 124.241966, 4.0], [7.23706, 124.695394, 1.0], [7.281569, 124.422813, 1.0], [7.301009, 124.683706, 1.0], [7.310695, 124.780982, 1.0], [7.333211, 124.56839, 1.0], [7.362014, 125.70565, 1.0], [7.452627, 122.328205, 1.0], [7.464961, 124.187111, 1.0], [7.492389, 124.724974, 1.0], [7.507152, 122.941414, 1.0], [7.514969, 124.372309, 1.0], [7.517844, 124.372113, 1.0], [7.579152, 123.16669, 1.0], [7.590722, 122.143841, 2.0], [7.612788, 123.005931, 1.0], [7.686119, 124.692186, 1.0], [7.732345, 123.057305, 1.0], [7.742853, 124.70475, 1.0], [7.785306, 122.592856, 1.0], [7.794568, 122.788106, 1.0], [7.80121, 122.759801, 1.0], [7.807908, 122.699403, 1.0], [7.823071, 126.055367, 1.0], [7.825203, 123.437378, 1.0], [7.829613, 123.436756, 1.0], [7.860251, 124.130054, 1.0], [7.864016, 123.514551, 1.0], [8.003105, 124.289666, 1.0], [8.004674, 124.2913, 1.0], [8.020031, 124.056593, 1.0], [8.065973, 124.260404, 1.0], [8.115408, 123.896522, 1.0], [8.190899, 124.087955, 1.0], [8.486803, 124.645818, 3.0], [10.728829, 123.82764, 1.0], [14.346627, 121.05041, 1.0], [14.599352, 120.984772, 2.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_afb7022515b8ac9857c09fca74f9844a.addTo(map_33fd662c1b0d5752e7eea0f207eb56db);
#
#
#             tile_layer_cc2355d20057324dd2813aa41a36de07.addTo(map_33fd662c1b0d5752e7eea0f207eb56db);
#
#
#             heat_map_afb7022515b8ac9857c09fca74f9844a.addTo(map_33fd662c1b0d5752e7eea0f207eb56db);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Tracing NPA Activity in the Philippines: A Heatmap from 1970 to 2017

# %%
# New People's Army (NPA
NPA_filter1 = global_terrorist[global_terrorist['country_txt'] == 'Philippines']

# %%
NPA_filter2 = NPA_filter1[NPA_filter1['gname'] == "New People's Army (NPA)"]

# %% [markdown]
# # NPA Activity in the Philippines from 1970 to 2017

# %%
coordinates = NPA_filter2.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
NPA_incidents = folium.Map(location = [12, 124.3], zoom_start =5.5)
HeatMap(heatmap_data).add_to(NPA_incidents)
NPA_incidents.save('terrorism_NPA_incidents.html')
NPA_incidents
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e1eff50e69ea75c7474bdd80a9b8ff3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e1eff50e69ea75c7474bdd80a9b8ff3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e1eff50e69ea75c7474bdd80a9b8ff3 = L.map(
#                 &quot;map_3e1eff50e69ea75c7474bdd80a9b8ff3&quot;,
#                 {
#                     center: [12.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer
124.063018, 1.0], [6.583669, 124.98903, 1.0], [6.61417, 125.236669, 2.0], [6.615473, 125.217184, 1.0], [6.616667, 125.216667, 1.0], [6.617372, 125.216648, 1.0], [6.621954, 124.571637, 1.0], [6.62734, 125.235645, 1.0], [6.633477, 124.600515, 1.0], [6.633826, 124.067887, 1.0], [6.634899, 125.082855, 1.0], [6.635278, 124.975, 1.0], [6.65197, 121.963683, 1.0], [6.654931, 124.979746, 1.0], [6.655411, 126.074136, 1.0], [6.670716, 124.523985, 1.0], [6.680243, 125.257566, 1.0], [6.682694, 125.019975, 1.0], [6.684672, 124.961654, 1.0], [6.697343, 125.082779, 3.0], [6.700414, 121.972557, 1.0], [6.704711, 125.212211, 1.0], [6.721638, 124.113104, 1.0], [6.723456, 125.231846, 1.0], [6.723931, 125.150235, 1.0], [6.742624, 125.204618, 1.0], [6.748065, 125.262741, 2.0], [6.750046, 125.35626, 7.0], [6.75235, 125.351378, 1.0], [6.759496, 125.350978, 1.0], [6.767153, 125.183237, 1.0], [6.767168, 125.182716, 1.0], [6.771603, 125.355757, 1.0], [6.781093, 125.210871, 1.0], [6.782214, 124.931511, 1.0], [6.784057, 125.217967, 2.0], [6.786284, 125.212718, 2.0], [6.79035, 125.205076, 1.0], [6.790861, 125.205552, 1.0], [6.809045, 125.192555, 1.0], [6.813901, 124.947252, 1.0], [6.815429, 125.3769, 1.0], [6.829826, 124.876845, 1.0], [6.83155, 124.874207, 1.0], [6.831959, 124.878863, 2.0], [6.832955, 124.884192, 1.0], [6.833333, 124.883333, 2.0], [6.833577, 126.195725, 1.0], [6.836642, 125.414305, 1.0], [6.836912, 125.413349, 2.0], [6.845575, 126.295997, 1.0], [6.846821, 125.417152, 1.0], [6.862833, 124.445136, 2.0], [6.873951, 125.449516, 1.0], [6.893056, 125.

# %% [markdown]
# # NPA Armed Assaults in the Philippines from 1970 to 2017

# %%
NPA_filter2['attacktype1_txt'].value_counts()
# Out:
# attacktype1_txt
# Armed Assault                          1087
# Bombing/Explosion                       481
# Assassination                           393
# Facility/Infrastructure Attack          345
# Hostage Taking (Kidnapping)             225
# Unknown                                 178
# Hostage Taking (Barricade Incident)      44
# Hijacking                                15
# Unarmed Assault                           2
# Name: count, dtype: int64

# %%
NPA_filter3 = NPA_filter2[NPA_filter2['attacktype1_txt']=='Armed Assault']
NPA_filter4 = NPA_filter2[NPA_filter2['attacktype1_txt']=='Bombing/Explosion']
NPA_filter5 = NPA_filter2[NPA_filter2['attacktype1_txt']=='Assassination']
NPA_filter6 = NPA_filter2[NPA_filter2['attacktype1_txt']=='Facility/Infrastructure Attack']
NPA_filter7 = NPA_filter2[NPA_filter2['attacktype1_txt']=='Hostage Taking (Kidnapping)']

# %%
coordinates = NPA_filter3.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
NPA_Armed_Assault_incidents = folium.Map(location = [12, 124.3], zoom_start =5.5)
HeatMap(heatmap_data).add_to(NPA_Armed_Assault_incidents)
NPA_Armed_Assault_incidents.save('terrorism_NPA_Armed_Assault_incidents.html')
NPA_Armed_Assault_incidents
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map
, 1.0], [11.701254, 122.363766, 1.0], [11.775031, 124.883423, 1.0], [12.026849, 123.693881, 1.0], [12.033378, 123.200461, 1.0], [12.268195, 125.369489, 1.0], [12.333827, 121.34998, 1.0], [12.35275, 121.06761, 1.0], [12.367922, 123.620761, 3.0], [12.503525, 124.637103, 1.0], [12.562855, 124.933601, 1.0], [12.611713, 124.055114, 1.0], [12.708158, 123.894143, 1.0], [12.716728, 121.382804, 1.0], [12.921375, 124.122678, 1.0], [12.943154, 124.06971, 1.0], [12.970187, 124.004177, 1.0], [12.99271, 124.014746, 1.0], [13.025418, 124.028392, 1.0], [13.186049, 123.540123, 1.0], [13.192288, 123.59917, 1.0], [13.240874, 123.537612, 1.0], [13.318923, 123.314933, 1.0], [13.413213, 121.175236, 1.0], [13.432636, 123.413066, 1.0], [13.560981, 123.374843, 2.0], [13.621255, 123.200351, 1.0], [13.7576, 121.058325, 1.0], [13.767671, 122.976515, 1.0], [13.820728, 122.791793, 1.0], [13.931052, 121.617683, 1.0], [13.962909, 121.526711, 1.0], [14.115558, 122.956465, 1.0], [14.301147, 121.111935, 1.0], [14.459238, 120.929034, 1.0], [14.483853, 121.014503, 1.0], [14.514697, 121.066055, 1.0], [14.549431, 121.033592, 1.0], [14.584232, 121.03904, 1.0], [14.596051, 120.978666, 89.0], [14.599352, 120.984772, 1.0], [14.647183, 121.103012, 1.0], [14.67428, 121.057495, 11.0], [14.679084, 120.539549, 5.0], [14.7166, 120.301567, 1.0], [14.799401, 120.926037, 1.0], [14.813849, 121.045151, 1.0], [14.83879

# %% [markdown]
# # Geographic Spread of Abu Sayyaf Terror Attacks in the Philippines (1991–2017)

# %%
# Abu Sayyaf Group (ASG)

# %%
ASG_filter1 = global_terrorist[global_terrorist['country_txt'] == 'Philippines']

# %%
ASG_filter2 = ASG_filter1[(ASG_filter1['iyear'] >= 1990) & (ASG_filter1['iyear'] <= 2017)]

# %%
ASG_filter3 = ASG_filter2[ASG_filter2['gname'] == "Abu Sayyaf Group (ASG)"]

# %%
coordinates = ASG_filter3.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
ASG_incidents = folium.Map(location = [12, 124.3], zoom_start =5.5)
HeatMap(heatmap_data).add_to(ASG_incidents)
ASG_incidents.save('terrorism_ASG_incidents.html')
ASG_incidents
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_745cf3669ceb4e872e75e7393b23e92b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_745cf3669ceb4e872e75e7393b23e92b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_745cf3669ceb4e872e75e7393b23e92b = L.map(
#                 &quot;map_745cf3669ceb4e872e75e7393b23e92b&quot;,
#                 {
#                     center: [12.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4107dd5528dc65a00f02b6d9f986ab1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4107dd5528dc65a00f02b6d9f986ab1.addTo(map_745cf3669ceb4e872e75e7393b23e92b);
#
#
#             var heat_map_ab69813e84da41130d9b7fbcc4640548 = L.heatLayer(
.0], [6.068588, 121.034669, 1.0], [6.069434, 121.032351, 1.0], [6.074574, 121.134326, 1.0], [6.077377, 121.082137, 1.0], [6.078236, 118.314049, 1.0], [6.078949, 118.314927, 1.0], [6.079257, 121.057255, 1.0], [6.084487, 121.085603, 1.0], [6.087954, 121.105416, 1.0], [6.088059, 121.099223, 1.0], [6.088221, 121.109329, 8.0], [6.089515, 121.105521, 1.0], [6.102634, 118.446977, 1.0], [6.11622, 125.169395, 4.0], [6.29059, 120.5657, 1.0], [6.30121, 120.573958, 1.0], [6.30158, 120.583999, 1.0], [6.301814, 120.583623, 1.0], [6.416943, 121.9835, 1.0], [6.41871, 121.972443, 12.0], [6.440039, 122.080475, 1.0], [6.440693, 121.958729, 1.0], [6.441898, 121.963071, 1.0], [6.448534, 121.968092, 1.0], [6.451931, 121.947789, 1.0], [6.451944, 121.947778, 1.0], [6.453899, 121.948123, 1.0], [6.462973, 122.171072, 1.0], [6.472241, 122.040186, 1.0], [6.474417, 122.105078, 1.0], [6.482175, 122.165286, 1.0], [6.482311, 121.96159, 1.0], [6.482905, 122.015549, 1.0], [6.484444, 122.140556, 1.0], [6.486859, 121.913314, 1.0], [6.487222, 121.978333, 4.0], [6.490778, 121.972431, 1.0], [6.491326, 122.143443, 1.0], [6.491515, 122.141717, 1.0], [6.493148,

# %%
ASG_filter3['attacktype1_txt'].value_counts()
# Out:
# attacktype1_txt
# Bombing/Explosion                      209
# Hostage Taking (Kidnapping)            162
# Armed Assault                           98
# Assassination                           16
# Hijacking                                9
# Unknown                                  8
# Facility/Infrastructure Attack           4
# Hostage Taking (Barricade Incident)      2
# Name: count, dtype: int64

# %%
ASG_filter4 = ASG_filter3[ASG_filter3['attacktype1_txt']=='Bombing/Explosion']
ASG_filter5 = ASG_filter3[ASG_filter3['attacktype1_txt']=='Hostage Taking (Kidnapping)']

# %%
coordinates = ASG_filter4.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
ASG_Bombing_incidents = folium.Map(location = [12, 124.3], zoom_start =5.5)
HeatMap(heatmap_data).add_to(ASG_Bombing_incidents)
ASG_Bombing_incidents.save('terrorism_ASG_Bombing_incidents.html')
ASG_Bombing_incidents
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5862e3ff9ef03effc2a06cb58c5d3241 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5862e3ff9ef03effc2a06cb58c5d3241&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5862e3ff9ef03effc2a06cb58c5d3241 = L.map(
#                 &quot;map_5862e3ff9ef03effc2a06cb58c5d3241&quot;,
#                 {
#                     center: [12.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1afaf51eab4aff1cc305b5ff979559b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1afaf51eab4aff1cc305b5ff979559b.addTo(map_5862e3ff9ef03effc2a06cb58c5d3241);
#
#
#             var heat_map_0ea4da11844f5bb2687183199dc1be25 = L.heatLayer(

#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coordinates = ASG_filter5.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
ASG_Kidnapping_incidents = folium.Map(location = [12, 124.3], zoom_start =5.5)
HeatMap(heatmap_data).add_to(ASG_Kidnapping_incidents)
ASG_Kidnapping_incidents.save('terrorism_ASG_Kidnapping_incidents.html')
ASG_Kidnapping_incidents
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9849e3da7779a2fc1041e2282e5797f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9849e3da7779a2fc1041e2282e5797f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9849e3da7779a2fc1041e2282e5797f = L.map(
#                 &quot;map_d9849e3da7779a2fc1041e2282e5797f&quot;,
#                 {
#                     center: [12.0, 124.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9ed8c2a3f90c134d06f454e72667cde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9ed8c2a3f90c134d06f454e72667cde.addTo(map_d9849e3da7779a2fc1041e2282e5797f);
#
#
#             var heat_map_049cea294f1fc050b738afb10e553e51 = L.heatLayer(
#                 [[4.662801, 119.399601, 1.0], [4.897277, 119.84869, 1.0], [5.010223, 119.747485, 1.0], [5.030788, 119.775053, 1.0], [5.032286, 119.772924, 1.0], [5.13691, 119.945966, 1.0], [5.184828, 120.013958, 1.0], [5.544054, 120.815636, 2.0], [5.553923, 120.913233, 1.0], [5.821566, 125.200949, 1.0], [5.9137, 120.9056, 4.0], [5.917386, 120.99701, 1.0], [5.927787, 121.028412, 1.0], [5.933405, 121.033258, 1.0], [5.933719, 120.999035, 1.0], [5.952552, 121.168179, 1.0], [5.960634, 120.961543, 1.0], [5.96147, 120.988483, 1.0], [5.969181, 121.125214, 1.0], [5.976337, 121.223427, 1.0], [5.977475, 121.115015, 1.0], [5.989123, 120.953132, 1.0], [5.989683, 121.039697, 2.0], [5.996383, 121.107944, 1.0], [6.016509, 120.992552, 1.0], [6.019005, 121.121649, 1.0], [6.021834, 121.16568, 1.0], [6.031285, 120.971924, 1.0], [6.036952, 121.037821, 1.0], [6.04343, 120.994263, 2.0], [6.048709, 121.029146, 1.0], [6.050458, 121.012245, 13.0], [6.050894, 120.993495, 1.0], [6.051232, 120.999851, 1.0], [6.053554, 121.059576, 1.0], [6.053897, 121.002855, 1.0], [6.05519, 121.001323, 2.0], [6.055578, 121.039629, 1.0], [6.063022, 121.102294, 2.0], [6.066456, 121.100121, 1.0], [6.066546, 121.100221, 1.0], [6.066667, 121.1, 3.0], [6.066812, 121.100482, 1.0], [6.066868, 121.100121, 1.0], [6.067685, 121.099724, 1.0], [6.068482, 121.034231, 1.0], [6.078236, 118.314049, 1.0], [6.078949, 118.314927, 1.0], [6.079257, 121.057255, 1.0], [6.084487, 121.085603, 1.0], [6.088221, 121.109329, 4.0], [6.29059, 120.5657, 1.0], [6.30121, 120.573958, 1.0], [6.30158, 120.583999, 1.0], [6.301814, 120.583623, 1.0], [6.416943, 121.9835, 1.0], [6.41871, 121.972443, 1.0], [6.453899, 121.948123, 1.0], [6.490778, 121.972431, 1.0], [6.497216, 122.105141, 1.0], [6.503613, 122.065841, 1.0], [6.51792, 122.12822, 1.0], [6.529908, 121.910195, 1.0], [6.533711, 122.083978, 1.0], [6.539852, 121.872945, 1.0], [6.545399, 121.873756, 3.0], [6.556828, 121.883449, 1.0], [6.570331, 122.05425, 1.0], [6.575322, 122.024186, 1.0], [6.582303, 122.179241, 1.0], [6.596997, 121.907486, 1.0], [6.598449, 122.040153, 1.0], [6.599126, 121.903267, 1.0], [6.599402, 121.904055, 1.0], [6.599405, 121.904057, 1.0], [6.606469, 122.192254, 1.0], [6.619005, 122.256968, 1.0], [6.62139, 122.143825, 1.0], [6.644421, 122.273133, 1.0], [6.645308, 122.10184, 5.0], [6.645556, 122.101944, 1.0], [6.660501, 122.138992, 2.0], [6.664421, 122.185398, 1.0], [6.700414, 121.972557, 3.0], [6.703352, 121.968689, 2.0], [6.704221, 121.973842, 1.0], [6.705001, 121.970605, 1.0], [6.720228, 122.030205, 1.0], [6.887752, 122.154588, 1.0], [6.929089, 122.07885, 7.0], [6.950278, 121.981389, 1.0], [6.961095, 122.143376, 1.0], [7.037435, 118.511496, 1.0], [7.075778, 125.587755, 1.0], [7.209594, 124.241966, 1.0], [7.291386, 122.064633, 1.0], [7.307012, 122.845741, 1.0], [7.317287, 122.875178, 1.0], [7.451227, 123.313767, 1.0], [7.548409, 122.338157, 1.0], [7.582127, 122.856814, 1.0], [7.585122, 122.142525, 1.0], [7.659503, 122.469391, 1.0], [7.674924, 123.152963, 1.0], [7.706753, 122.138522, 1.0], [7.746118, 122.967087, 1.0], [7.761796, 122.582514, 1.0], [7.769235, 123.133354, 1.0], [7.78403, 122.593085, 1.0], [7.784172, 122.583282, 1.0], [7.785306, 122.592856, 1.0], [7.790212, 122.783317, 1.0], [7.807529, 122.701115, 1.0], [8.066727, 122.516607, 1.0], [8.110727, 122.7883, 1.0], [8.582775, 123.342894, 1.0], [8.673704, 117.627555, 1.0], [9.783552, 124.301971, 1.0], [9.915267, 118.877188, 1.0], [10.338213, 123.942398, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_049cea294f1fc050b738afb10e553e51.addTo(map_d9849e3da7779a2fc1041e2282e5797f);
#
#
#             tile_layer_a9ed8c2a3f90c134d06f454e72667cde.addTo(map_d9849e3da7779a2fc1041e2282e5797f);
#
#
#             heat_map_049cea294f1fc050b738afb10e5

# %% [markdown]
# <h1>Activity 6</h1>

# %% [markdown]
# <h3>Regional Analysis</h3>

# %%
global_terrorist['region_txt'].value_counts()
# Out:
# region_txt
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: count, dtype: int64

# %%
Terro_SoutheastAsia = global_terrorist[global_terrorist['region_txt'] == 'Southeast Asia']

# %%
# Terro_SoutheastAsia['country_txt'].value_counts()
Targtype_southeastasia = Terro_SoutheastAsia['targtype1_txt']

# %%
filter_1 = Terro_SoutheastAsia[Terro_SoutheastAsia['targtype1_txt'] == "Private Citizens & Property"]

# %% [markdown]
# <h1>Heatmap of Terrorist Incidents Targeting Private Citizens & Property in Southeast Asia</h1>

# %%
coordinates = filter_1.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
#         <li>Utilities – 382 cases (2.59%)</li>
#         <li>Religious Figures/Institutions – 341 cases (2.31%)</li>
#         <li>Unknown – 292 cases (1.98%)</li>
#         <li>Journalists & Media – 166 cases (1.12%)</li>
#         <li>Telecommunication – 156 cases (1.06%)</li>
#         <li>Government (Diplomatic) – 124 cases (0.84%)</li>
#         <li>Terrorists/Non-State Militia – 78 cases (0.53%)</li>
#         <li>Maritime – 74 cases (0.50%)</li>
#         <li>Airports & Aircraft – 50 cases (0.34%)</li>
#         <li>NGO – 43 cases (0.29%)</li>
#         <li>Tourists – 34 cases (0.23%)</li>
#         <li>Food or Water Supply – 23 cases (0.16%)</li>
#         <li>Violent Political Party – 12 cases (0.08%)</li>
#         <li>Other – 9 cases (0.06%)</li>
#     </ul>

# %%
# Terro_SoutheastAsia = global_terrorist[global_terrorist['region_txt'] == 'Southeast Asia']
filter2 = Terro_SoutheastAsia[Terro_SoutheastAsia['attacktype1_txt'] == 'Armed Assault']

# %%
filter2['country_txt'].value_counts()
# Out:
# country_txt
# Philippines    2158
# Thailand       1420
# Indonesia       245
# Myanmar         110
# Cambodia         62
# Malaysia         13
# Laos             10
# East Timor        3
# Vietnam           1
# Name: count, dtype: int64

# %% [markdown]
# # Armed Assault attacks in Southeast Asia through the years

# %%
coordinates = filter2.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()) / (coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
terror_map_SoutheaseAsia_armedAssault_Incident = folium.Map(location=[14, 115], zoom_start=4.4)
HeatMap(heatmap_data).add_to(terror_map_SoutheaseAsia_armedAssault_Incident)
terror_map_SoutheaseAsia_armedAssault_Incident.save('SoutheaseAsia_armedAssault_Incident.html')
terror_map_SoutheaseAsia_armedAssault_Incident
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b9c3d9753de3f9387349fa8ab8daebf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b9c3d9753de3f9387349fa8ab8daebf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b9c3d9753de3f9387349fa8ab8daebf = L.map(
#                 &quot;map_3b9c3d9753de3f9387349fa8ab8daebf&quot;,
#                 {
#                     center: [14.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4.4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_502b9e871fda55047b18a2202d735bd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_502b9e871fda55047b18a2202d735bd3.addTo(map_3b9c3d9753de3f9387349fa8ab8daebf);
#
#
#             var heat_map_69bc9e9e8d0c41d4f329c405f51c9aae = L.heatLayer(
#                 [[-9.446667, 124.478056, 1.0], [-9.296778, 124.282588, 1.0], [-9.104512, 124.897553, 3.0], [-9.017001, 125.829397, 1.0], [-8.983333, 125.216667, 1.0], [-8.92707, 125.225323, 1.0], [-8.925, 125.375833, 1.0], [-8.913945, 126.280736, 1.0], [-8.867896, 125.704607, 1.0], [-8.8575, 126.364722, 1.0], [-8.838056, 125.597222, 1.0], [-8.80954, 125.1585, 1.0], [-8.758333, 125.2075, 1.0], [-8.65299, 117.366908, 1.0], [-8.583333, 125.35, 1.0], [-8.560655, 125.584969, 1.0], [-8.55902, 125.578194, 7.0], [-8.556944, 125.581667
1.0], [-1.395818, 120.75453, 1.0], [-1.394556, 120.754062, 1.0], [-1.393746, 120.755887, 1.0], [-1.393147, 120.754749, 2.0], [-1.342116, 121.655155, 1.0], [-1.267704, 120.576326, 1.0], [-1.165474, 119.886186, 1.0], [-1.112057, 101.615777, 1.0], [-0.928863, 119.871135, 1.0], [-0.898583, 119.850601, 1.0], [-0.896722, 119.857299, 1.0], [-0.861453, 134.062042, 1.0], [-0.494823, 117.143615, 1.0], [0.559, 121.211122, 1.0], [0.581565, 120.803539, 1.0], [0.783333, 127.366667, 1.0], [2.287274, 111.83057, 2.0], [2.495129, 128.637253, 1.0], [2.553629, 128.610928, 1.0], [2.64413, 97.790807, 1.0], [2.91856, 101.665446, 1.0], [3.015301, 101.712396, 1.0], [3.138943, 101.691315, 1.0], [3.192995, 101.592343, 1.0], [3.193265, 98.30584, 1.0], [3.265931, 97.177063, 1.0], [3.426665, 97.080959, 1.0], [3.585242, 98.675598, 3.0], [3.59143, 98.669477, 1.0], [3.59566

# %% [markdown]
# <h1>No. 2 Somalia</h1>

# %%
global_terrorist['region_txt'].value_counts()
# Out:
# region_txt
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: count, dtype: int64

# %%
filter1 = global_terrorist[global_terrorist['region_txt'] == 'Sub-Saharan Africa']

# %%
filter1['country_txt'].value_counts().head()
# Out:
# country_txt
# Somalia                             4142
# Nigeria                             3907
# South Africa                        2016
# Sudan                                967
# Democratic Republic of the Congo     775
# Name: count, dtype: int64

# %%
filter2 = filter1[filter1['country_txt'] == 'Somalia']

# %%
# filter2['attacktype1_txt'].value_counts().head()
# Out:
# attacktype1_txt
# Bombing/Explosion              1636
# Armed Assault                  1173
# Assassination                   484
# Unknown                         381
# Hostage Taking (Kidnapping)     355
# Name: count, dtype: int64

# %%
# filter3 =  filter2[filter2['iyear'] == 2014]

# %%
filter4 = filter2[filter2['city'] == 'Mogadishu']
filter4['attacktype1_txt'].value_counts()
# Out:
# attacktype1_txt
# Bombing/Explosion                      767
# Armed Assault                          439
# Assassination                          251
# Hostage Taking (Kidnapping)             55
# Unknown                                 49
# Hijacking                                9
# Hostage Taking (Barricade Incident)      6
# Facility/Infrastructure Attack           5
# Name: count, dtype: int64

# %% [markdown]
# <h1>Bombing and Explosion attacks in the Country of Somalia</h1>

# %%
coordinates = filter4.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()) / (coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
Somalia_bombing = folium.Map(location=[6, 48], zoom_start=5.2)
HeatMap(heatmap_data).add_to(Somalia_bombing)
Somalia_bombing.save('Somalia_bombing.html')
Somalia_bombing
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43032932f444c1372001c9b269120e73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43032932f444c1372001c9b269120e73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43032932f444c1372001c9b269120e73 = L.map(
#                 &quot;map_43032932f444c1372001c9b269120e73&quot;,
#                 {
#                     center: [6.0, 48.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5.2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07efaa8f1907b9382832781805e88495 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07efaa8f1907b9382832781805e88495.addTo(map_43032932f444c1372001c9b269120e73);
#
#
#             var heat_map_5f125bd653322f54766104c478e9468e = L.heatLayer(
#                 [[1.991886, 45.259645, 1.0], [2.002975, 45.273875, 1.0], [2.006809, 45.277001, 4.0], [2.009957, 45.270646, 1.0], [2.045011, 45.269905, 1.0], [2.052013, 45.27065, 11.0], [2.057167, 45.217489, 1.0], [2.059819, 45.326115, 1524.0], [2.072112, 45.221424, 2.0], [2.074612, 45.395388, 3.0], [2.078341, 45.40674, 3.0], [2.080788, 45.271236, 2.0], [2.080924, 45.271226, 1.0], [2.081587, 45.396551, 2.0], [2.082062, 45.207493, 3.0], [2.083988, 45.395178, 3.0], [2.084218, 45.39739, 1.0], [2.085211, 45.402806, 1.0], [2.085508, 45.402748, 1.0], [2.085509, 45.402748, 6.0], [2.085523, 45.40279, 1.0], [2.08577, 45.402886, 1.0], [2.085781, 45.402717, 1.0], [2.088511, 45.183648, 1.0], [2.103889, 45.465556, 1.0], [2.106139, 45.263414, 1.0], [2.133346, 45.300138, 1.0], [2.792833, 41.014359, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_5f125bd653322f54766104c478e9468e.addTo(map_43032932f444c1372001c9b269120e73);
#
#
#             tile_layer_07efaa8f1907b9382832781805e88495.addTo(map_43032932f444c1372001c9b269120e73);
#
#
#             heat_map_5f125bd653322f54766104c478e9468e.addTo(map_43032932f444c1372001c9b269120e73);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h1>Tracking the Taliban: Spatial Patterns and Attack Trends Across South Asia</h1>

# %%
taliban_filter1 = global_terrorist[global_terrorist['gname']== 'Taliban']

# %%
taliban_filter2 = taliban_filter1[taliban_filter1['region_txt'] == 'South Asia']

# %%
taliban_filter3 = taliban_filter2[(taliban_filter2['iyear'] >= 1995) & (taliban_filter2['iyear'] <= 2017)]

# %%
taliban_Afganistan_filter1 = taliban_filter3[taliban_filter3['country_txt'] == 'Afghanistan']

# %% [markdown]
# <h1>Tracking the Taliban: Taliban Incidents</h1>

# %%
coordinates = taliban_Afganistan_filter1.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()) / (coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_Afganistan = folium.Map(location=[35, 70], zoom_start=6, tiles='CartoDB Positron')
HeatMap(heatmap_data).add_to(taliban_Afganistan)
taliban_Afganistan.save('taliban_Afganistan.html')
taliban_Afganistan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a9a811a16db968db7546655e79f5542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a9a811a16db968db7546655e79f5542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a9a811a16db968db7546655e79f5542 = L.map(
#                 &quot;map_5a9a811a16db968db7546655e79f5542&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d346a35d96d19fe7af267961b44b72f7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_
667, 1.0], [31.178134, 66.606158, 1.0], [31.203056, 66.280556, 1.0], [31.220671, 65.749791, 1.0], [31.229915, 62.40743, 1.0], [31.240393, 66.607925, 1.0], [31.246279, 62.336189, 1.0], [31.277089, 64.248209, 1.0], [31.289389, 62.296432, 1.0], [31.302174, 64.264095, 1.0], [31.305401, 64.2593, 1.0], [31.306599, 64.260358, 1.0], [31.314139, 62.301835, 1.0], [31.319702, 65.959854, 1.0], [31.320556, 65.961111, 3.0], [31.326196, 63.971177, 2.0], [31.32762, 65.95002, 1.0], [31.351011, 63.944977, 1.0], [31.353637, 63.939571, 1.0], [31.363018, 63.982658, 1.0], [31.363647, 63.9586, 3.0], [31.363647, 63.958611, 34.0], [31.363648, 63.958562, 1.0], [31.363824, 63.958611, 1.0], [31.364396, 63.958611, 1.0], [31.365685, 63.961042, 1.0], [31.365759, 64.275538, 1.0], [31.370237, 64.329203, 1.0], [31.377331, 63.95188, 1.0], [31.380893, 67.237117, 1.0], [31.381779, 63.960686, 1.0], [31.382116, 64.348244, 1.0], [31.383046, 64.299565, 1.0], [31.383408, 67.239461, 1.0], [31.385607, 64.296067, 1.0], [31.386468, 65.986204, 1.0], [31.387285, 64.306967, 5.0], [31.389315, 64.315166, 3.0], [31.391036, 64.317788, 1.0], [31.391158, 65.598507, 1.0], [31.391814, 64.319022, 1.0], [31.393549, 65.835953, 1.0], [31.393889, 65.836667, 1.0], [31.404419, 64.31628, 1.0], [31.407546, 64.301962, 1.0],

# %% [markdown]
# <h1>Tracking the Taliban: Taliban with Markers of Incidents Counts</h1>

# %%
coordinates = taliban_Afganistan_filter1.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_Afganistan = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_Afganistan)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 20: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_Afganistan)

taliban_Afganistan.save('taliban_Afganistan.html')
taliban_Afganistan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25e42234be7978c3f1f594a612572d1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25e42234be7978c3f1f594a612572d1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25e42234be7978c3f1f594a612572d1c = L.map(
#                 &quot;map_25e42234be7978c3f1f594a612572d1c&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35ffe3b685f33a44609acff0280fee02 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35ffe3b685f33a44609acff0280fee02.addTo(map_25e42234be7978c3f1f594a612572d1c);
#
#
#             var heat_map_4a2078b44686d25e24b0efa3c8506b82 = L.heatLayer(
0], [31.302174, 64.264095, 1.0], [31.305401, 64.2593, 1.0], [31.306599, 64.260358, 1.0], [31.314139, 62.301835, 1.0], [31.319702, 65.959854, 1.0], [31.320556, 65.961111, 3.0], [31.326196, 63.971177, 2.0], [31.32762, 65.95002, 1.0], [31.351011, 63.944977, 1.0], [31.353637, 63.939571, 1.0], [31.363018, 63.982658, 1.0], [31.363647, 63.9586, 3.0], [31.363647, 63.958611, 34.0], [31.363648, 63.958562, 1.0], [31.363824, 63.958611, 1.0], [31.364396, 63.958611, 1.0], [31.365685, 63.961042, 1.0], [31.365759, 64.275538, 1.0], [31.370237, 64.329203, 1.0], [31.377331, 63.95188, 1.0], [31.380893, 67.237117, 1.0], [31.381779, 63.960686, 1.0], [31.382116, 64.348244, 1.0], [31.383046, 64.299565, 1.0], [31.383408, 67.239461, 1.0], [31.385607, 64.296067, 1.0], [31.386468, 65.986204, 1.0], [31.387285, 64.306967, 5.0], [31.389315, 64.315166, 3.0], [31.391036, 64.317788, 1.0], [31.391158, 65.598507, 1.0], [31.391814, 64.319022, 1.0], [31.393549, 65.835953, 1.0], [31.393889, 65.836667, 1.0], [31.404419, 64.31628, 1.0], [31.407546, 64.301962, 1.0],

# %% [markdown]
# <h1>Tracking the Taliban: Taliban Target Types with Markers of Incidents Counts</h1>

# %%
# taliban_Afganistan_filter1['targtype1_txt'].value_counts()
# taliban_Afganistan_filter1['targtype1_txt'].value_counts()

# %%
taliban_target1 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['targtype1_txt'] == 'Police']
taliban_target2 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['targtype1_txt'] == 'Military']
taliban_target3 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['targtype1_txt'] == 'Private Citizens & Property']
taliban_target4 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['targtype1_txt'] == 'Government (General)']

# %% [markdown]
# <h1>Tracking the Taliban: Mapping Police-Targeted Attacks with Incident Markers(more than 10 incidents)</h1>

# %%
coordinates = taliban_target1.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_target1 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_target1)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 10: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_target1)

taliban_target1.save('taliban_target1.html')
taliban_target1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6ae6e2ce808ded595b19b3e2962d8b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6ae6e2ce808ded595b19b3e2962d8b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6ae6e2ce808ded595b19b3e2962d8b4 = L.map(
#                 &quot;map_c6ae6e2ce808ded595b19b3e2962d8b4&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_
.506337, 65.421682, 1.0], [31.508661, 65.434448, 1.0], [31.508707, 62.700645, 2.0], [31.511396, 64.111862, 1.0], [31.513958, 64.926378, 1.0], [31.515347, 67.521606, 1.0], [31.515436, 65.17141, 1.0], [31.516389, 65.171667, 1.0], [31.516535, 65.400057, 1.0], [31.516754, 64.11309, 1.0], [31.51716, 64.114227, 1.0], [31.517771, 64.114227, 5.0], [31.518389, 64.116403, 1.0], [31.529604, 64.232224, 2.0], [31.5343, 64.250253, 1.0], [31.544476, 65.484566, 1.0], [31.547778, 65.454167, 1.0], [31.550039, 65.45263, 2.0], [31.553875, 64.117058, 1.0], [31.557064, 64.87709, 2.0], [31.558117, 64.117218, 1.0], [31.558611, 65.329167, 1.0], [31.57044, 62.823462, 1.0], [31.571955, 65.741539, 1.0], [31.57276, 67.042618, 2.0], [31.577061, 66.517975, 1.0], [31.583061, 64.369167, 1.0], [31.583543, 64.348963, 1.0], [31.585088, 65.822786, 1.0], [31.587415, 64.373355, 1.0], [31.588103, 64.231534, 1.0], [31.589827, 64.337952, 5.0], [31.597309, 63.848269, 1.0], [31.598149, 63.864057, 1.0], [31.60063, 64.369652, 45.0], [31.604685, 64.368945, 1.0], [31.607109, 65.634674, 1.0], [31.60718, 67.523171, 1.0], [31.6119, 65.6811, 1.0], [31.612633, 65.681552, 1.0], [31.612835, 65.70216, 1.0], [31.617667, 65.675942, 4.0], [31.619314, 65.050156, 2.0], [31.619403, 65.054082, 1.0], [31.62071, 65.048938, 1.0], [31.621808, 65.053717, 1.0], [31.622276, 65.054543, 1.0], [31.622827, 62.869366, 4.0], [31.62284, 65.054425, 1.0],

# %% [markdown]
# <h1>Tracking the Taliban: Mapping Military-Targeted Attacks with Incident Markers(more than 10 incidents)</h1>

# %%
coordinates = taliban_target2.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_target2 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_target2)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 10: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_target2)

taliban_target2.save('taliban_target2.html')
taliban_target2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f9c26fd3b3e8e5f8670458e05a4a673 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f9c26fd3b3e8e5f8670458e05a4a673&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f9c26fd3b3e8e5f8670458e05a4a673 = L.map(
#                 &quot;map_2f9c26fd3b3e8e5f8670458e05a4a673&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b051a1532969532f9ca740a70e591f7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_
, 1.0], [31.65, 65.65, 1.0], [31.65192, 64.209541, 1.0], [31.658451, 64.329544, 1.0], [31.661526, 63.005497, 1.0], [31.662216, 64.260976, 1.0], [31.662415, 62.935134, 1.0], [31.662674, 63.014758, 2.0], [31.662675, 63.014758, 1.0], [31.664218, 64.26615, 1.0], [31.664231, 63.003069, 1.0], [31.665015, 65.495156, 2.0], [31.680202, 64.31221, 1.0], [31.688299, 64.416763, 1.0], [31.693083, 64.519066, 1.0], [31.716272, 64.400316, 1.0], [31.72807, 64.710282, 1.0], [31.733333, 65.133333, 1.0], [31.73586, 62.910394, 1.0], [31.7472, 64.44207, 1.0], [31.749787, 64.442311, 1.0], [31.76147, 64.621428, 4.0], [31.765215, 64.694007, 1.0], [31.766705, 64.618607, 1.0], [31.783843, 64.698619, 1.0], [31.784801, 65.755234, 1.0], [31.784874, 64.698129, 1.0], [31.78801, 65.570785, 1.0], [31.789021, 64.688484, 2.0], [31.789944, 64.58947, 1.0], [31.793611, 64.685, 1.0], [31.793618, 64.685, 1.0], [31.80262, 66.324715, 3.0], [31.803363, 66.323613, 1.0], [31.81468, 64.548236, 2.0], [31.815914, 64.571647, 1.0], [31.816665, 64.549994, 1.0], [31.817678, 64.55125, 1.0], [31.82012, 64.567716, 1.0], [31.823601, 64.564087, 2.0], [31.824331, 64.557856, 1.0], [31.824747, 64.573959, 1.0], [31.825517, 6

# %% [markdown]
# <h1>Tracking the Taliban: Mapping Private Citizens & Property Targeted Attacks with Incident Markers(more than 10 incidents)</h1>

# %%
coordinates = taliban_target3.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_target3 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_target3)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 10: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_target3)

taliban_target3.save('taliban_target3.html')
taliban_target3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_616c26e9664b5b0479a176a4a76fc44f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_616c26e9664b5b0479a176a4a76fc44f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_616c26e9664b5b0479a176a4a76fc44f = L.map(
#                 &quot;map_616c26e9664b5b0479a176a4a76fc44f&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15b1d03129cb58e472b7689922fa593f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15b1d03129cb58e472b7689922fa593f.addTo(map_616c26e9664b5b0479a176a4a76fc44f);
#
#
#             var heat_map_727d57be25537d56562c885d1199ba21 = L.heatLayer(
, 63.014758, 1.0], [31.667667, 63.014758, 1.0], [31.678215, 64.899818, 1.0], [31.680202, 64.31221, 1.0], [31.685279, 63.029938, 1.0], [31.692616, 64.653328, 1.0], [31.705032, 65.689628, 1.0], [31.707778, 67.295278, 1.0], [31.717654, 65.690575, 1.0], [31.72737, 64.545981, 1.0], [31.735853, 62.910239, 1.0], [31.746087, 65.722945, 1.0], [31.750286, 67.316571, 1.0], [31.753857, 64.715928, 1.0], [31.76147, 64.621428, 2.0], [31.78801, 65.570785, 2.0], [31.80262, 66.324715, 1.0], [31.802901, 65.948879, 1.0], [31.803333, 66.323611, 1.0], [31.816698, 64.549747, 1.0], [31.823601, 64.564087, 1.0], [31.823984, 67.775917, 1.0], [31.825871, 64.576431, 12.0], [31.826695, 64.56407, 1.0], [31.829241, 64.568286, 1.0], [31.856434, 65.666684, 1.0], [31.890783, 61.42258, 1.0], [31.908611, 67.646111, 2.0], [31.908724, 67.646103, 1.0], [31.955699, 65.527103, 1.0], [31.979603, 67.05043, 1.0], [31.987162, 67.055824, 1.0], [32.003746, 65.947528, 1.0], [32.011862, 65.00

# %% [markdown]
# <h1>Tracking the Taliban: Mapping Government-Targeted Attacks with Incident Markers(more than 10 incidents)</h1>

# %%
coordinates = taliban_target4.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_target4 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_target4)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 10: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_target4)

taliban_target4.save('taliban_target3.html')
taliban_target4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aeabba89bd9c7dc5882b687d9757721f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aeabba89bd9c7dc5882b687d9757721f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aeabba89bd9c7dc5882b687d9757721f = L.map(
#                 &quot;map_aeabba89bd9c7dc5882b687d9757721f&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a73c21fbab5511ddeb148f0b61c84c7b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a73c21fbab5511ddeb148f0b61c84c7b.addTo(map_aeabba89bd9c7dc5882b687d9757721f);
#
#
#             var heat_map_b965a9731031673ff4f01d2c29338815 = L.heatLayer(
#                 [[30.094363, 65.285708, 1.0], [30.550198, 63.78606, 3.0], [30.959932, 61.86895, 9.0], [30.996068, 65.475736, 2.0], [31.002735, 66.405617, 3.0], [31.008066, 66.398042, 1.0], [31.131462, 64.213484, 1.0], [31.13251, 64.2129, 1.0], [31.132534, 64.212871, 1.0], [31.277089, 64.248209, 1.0], [31.319702, 65.959854, 1.0], [31.351011, 63.944977, 1.0], [31.353637, 63.939571, 1.0], [31.363647, 63.9586, 1.0], [31.363647, 63.958611, 6.0], [31.387285, 64.306967, 1.0], [31.389315, 64.315166,
 1.0], [32.625149, 62.479768, 3.0], [32.625149, 62.479769, 1.0], [32.630883, 66.767491, 2.0], [32.666404, 65.903629, 2.0], [32.666404, 65.90363, 1.0], [32.677064, 67.71391, 1.0], [32.677851, 61.981391, 4.0], [32.689845, 62.732388, 1.0], [32.740789, 67.624498, 1.0], [32.741089, 66.29187, 1.0], [32.771313, 69.07318, 3.0], [32.812872, 67.767124, 1.0], [32.81493, 67.766708, 1.0], [32.816136, 67.762998, 4.0], [32.853333, 68.449722, 1.0], [32.861304, 67.180975, 2.0], [32.861513, 69.126826, 2.0], [32.910299, 68.882423, 1.0], [32.918791, 66.145506, 1.0], [32.921305, 68.647104, 1.0], [32.922049, 65.623048, 1.0], [32.923889, 65.538889, 1.0], [32.924223, 66.144692, 1.0], [32.927129, 66.141526, 1.0], [32.

# %% [markdown]
# <h1>Tracking the Taliban: Taliban Attack Types with Markers of Incidents Counts</h1>

# %%
# taliban_Afganistan_filter1['attacktype1_txt'].value_counts()

# %%
# taliban_attack1 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['attacktype1_txt'] == 'Unknown']
taliban_attack1 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['attacktype1_txt'] == 'Bombing/Explosion']
taliban_attack2 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['attacktype1_txt'] == 'Armed Assault']
taliban_attack3 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['attacktype1_txt'] == 'Hostage Taking (Kidnapping)']
taliban_attack4 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['attacktype1_txt'] == 'Assassination']
taliban_attack5 = taliban_Afganistan_filter1[taliban_Afganistan_filter1['attacktype1_txt'] == 'Facility/Infrastructure Attack']

# %%
# taliban_attack1

# %% [markdown]
# <h1>Tracking the Taliban: Tracking the Taliban: Mapping Bombings and Explosions Across Afghanistan with Incident Markers</h1>

# %%
coordinates = taliban_attack1.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_attack_1 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_attack_1)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 1: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_attack_1)

taliban_attack_1.save('taliban_attack_1.html')
taliban_attack_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eefb90628845d408b5673ef49b97c624 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eefb90628845d408b5673ef49b97c624&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eefb90628845d408b5673ef49b97c624 = L.map(
#                 &quot;map_eefb90628845d408b5673ef49b97c624&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d28f001fa8e8c469c980bec6b6d61aa7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_
.321388, 1.0], [31.488245, 64.321492, 1.0], [31.496295, 65.001476, 1.0], [31.498301, 65.001164, 1.0], [31.498644, 65.214989, 1.0], [31.499139, 65.842823, 1.0], [31.499439, 65.000724, 1.0], [31.499713, 65.000854, 4.0], [31.502876, 65.845241, 1.0], [31.506944, 65.8475, 1.0], [31.508707, 62.700645, 1.0], [31.509225, 65.813909, 1.0], [31.509326, 65.814182, 1.0], [31.515113, 64.998002, 1.0], [31.515436, 65.17141, 1.0], [31.516389, 65.171667, 1.0], [31.516535, 65.400057, 1.0], [31.516548, 65.870557, 1.0], [31.517771, 64.114227, 3.0], [31.518389, 64.116403, 1.0], [31.529886, 65.027962, 1.0], [31.531478, 65.204949, 1.0], [31.533112, 65.186255, 1.0], [31.535048, 65.169029, 1.0], [31.538075, 65.055064, 1.0], [31.538883, 64.897282, 1.0], [31.540556, 65.333611, 1.0], [31.542267, 65.369281, 1.0], [31.543431, 64.073424, 1.0], [31.544476, 65.484566, 4.0], [31.547762, 65.454082, 1.0], [31.547778, 65.454167, 4.0], [31.550039, 65.45263, 3.0], [31.553378, 64.047439, 1.0], [31.555271, 65.062833, 1.0], [31.557064, 64.87709, 1.0], [31.558117, 64.117218, 1.0], [31.558611, 65.329167, 1.0], [31.563177, 65.664703, 1.0], [31.567253, 65.72559, 1.0], [31.571955, 65.741539, 1.0], [31.572686, 67.042324, 1.0], [31.57276, 67.042618, 3.0], [31.573838, 67.040911, 2.0], [31.577061, 66.517975,

# %%
coordinates = taliban_attack2.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_attack_2 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_attack_2)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 1: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_attack_2)

taliban_attack_2.save('taliban_attack_2.html')
taliban_attack_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64f20087c240a3acc3e7419e16000980 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64f20087c240a3acc3e7419e16000980&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64f20087c240a3acc3e7419e16000980 = L.map(
#                 &quot;map_64f20087c240a3acc3e7419e16000980&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95f5df8f29f2860497ec4f1c16fb8c10 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95f5df8f29f2860497ec4f1c16fb8c10.addTo(map_64f20087c240a3acc3e7419e16000980);
#
#
#             var heat_map_d1bd579d6c320aee0686fde8c191eec9 = L.heatLayer(
.0], [31.631083, 65.742226, 30.0], [31.635141, 64.243013, 1.0], [31.637821, 64.237801, 1.0], [31.639364, 64.574402, 1.0], [31.63957, 64.239832, 1.0], [31.64, 64.24, 3.0], [31.640079, 64.240209, 1.0], [31.640278, 65.3975, 5.0], [31.641306, 65.401251, 1.0], [31.645562, 66.544168, 1.0], [31.647876, 67.177831, 1.0], [31.656905, 65.033267, 1.0], [31.657277, 64.268052, 1.0], [31.658057, 63.017149, 2.0], [31.660395, 63.019896, 1.0], [31.662674, 63.014758, 5.0], [31.662675, 63.014758, 1.0], [31.663404, 64.24642, 1.0], [31.664218, 64.26615, 1.0], [31.665015, 65.495156, 2.0], [31.665838, 64.267577, 1.0], [31.6672, 64.354401, 2.0], [31.680202, 64.31221, 2.0], [31.685279, 63.029938, 2.0], [31.688299, 64.416763, 1.0], [31.693083, 64.519066, 1.0], [31.707778, 67.295278, 1.0], [31.71028, 65.680099, 1.0], [31.713611, 61.6225, 1.0], [31.725003, 61.63853, 1.0], [31.72807, 64.710282, 1.0], [31.7472, 64.44207, 1.0], [31.750606, 64.442613, 1.0], [31.7

# %%
coordinates = taliban_attack3.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_attack_3 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_attack_3)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 1: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_attack_3)

taliban_attack_3.save('taliban_attack_3.html')
taliban_attack_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66c4a843855c8e92a0b380e5f2857ec3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66c4a843855c8e92a0b380e5f2857ec3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66c4a843855c8e92a0b380e5f2857ec3 = L.map(
#                 &quot;map_66c4a843855c8e92a0b380e5f2857ec3&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9454b2d91b2224047c34460e21f3680d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9454b2d91b2224047c34460e21f3680d.addTo(map_66c4a843855c8e92a0b380e5f2857ec3);
#
#
#             var heat_map_fa789ae42d5435a7bf05835dbb3ced57 = L.heatLayer(
#                 [[30.094363, 65.285708, 1.0], [30.280606, 62.054597, 1.0], [30.81984, 64.177316, 1.0], [30.935697, 64.150011, 1.0], [31.026149, 62.450415, 2.0], [31.1225, 64.204722, 1.0], [31.319702, 65.959854, 1.0], [31.320556, 65.961111, 1.0], [31.363647, 63.9586, 2.0], [31.363647, 63.958611, 4.0], [31.461224, 66.52239, 1.0], [31.476493, 64.290059, 1.0], [31.503056, 65.561944, 1.0], [31.544476, 65.484566, 1.0], [31.583493, 63.791712, 1.0], [31.589827, 64.337952, 1.0], [31.60063, 64.369652, 3.0], [31.607109, 65.634674, 1.0], [31.608844, 65.052291, 1.0], [31.617
482928, 1.0], [32.627596, 62.469832, 1.0], [32.627893, 65.878367, 1.0], [32.628228, 65.87576, 1.0], [32.677064, 67.71391, 2.0], [32.677851, 61.981391, 5.0], [32.689845, 62.732388, 1.0], [32.708333, 65.863611, 1.0], [32.740789, 67.624498, 1.0], [32.741089, 66.29187, 1.0], [32.749992, 62.586651, 1.0], [32.771313, 69.07318, 2.0], [32.77789, 61.656727, 2.0], [32.806169, 67.463926, 1.0], [32.812872, 67.767124, 1.0], [32.816136, 67.762998, 1.0], [32.847222, 66.05, 1.0], [32.84974, 66.042742, 1.0], [32.88216, 66.127197, 1.0], [32.900865, 67.51743, 1.0], [32.910299, 68.882423, 1.0], [32.918791, 66.145506, 1.0], [32.927129, 66.141526, 3.0], [32.9

# %%
coordinates = taliban_attack4.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_attack_4 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_attack_4)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 1: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_attack_4)

taliban_attack_4.save('taliban_attack_4.html')
taliban_attack_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3804b89ca6da3979477ac9275c63fbb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3804b89ca6da3979477ac9275c63fbb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3804b89ca6da3979477ac9275c63fbb4 = L.map(
#                 &quot;map_3804b89ca6da3979477ac9275c63fbb4&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8eb721c406f7d99a61bb5c3638b194a9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8eb721c406f7d99a61bb5c3638b194a9.addTo(map_3804b89ca6da3979477ac9275c63fbb4);
#
#
#             var heat_map_3a6b718259703231aa082265b4610526 = L.heatLayer(
#                 [[30.094363, 65.285708, 1.0], [30.550198, 63.78606, 1.0], [30.622013, 64.031136, 1.0], [30.956481, 66.168925, 1.0], [30.959932, 61.86895, 4.0], [30.996068, 65.475736, 2.0], [31.002735, 66.405617, 2.0], [31.007884, 66.397578, 1.0], [31.12993, 64.19502, 1.0], [31.132154, 64.212844, 1.0], [31.277089, 64.248209, 1.0], [31.302174, 64.264095, 1.0], [31.314139, 62.301835, 1.0], [31.363647, 63.958611, 3.0], [31.382116, 64.348244, 1.0], [31.467463, 64.092445, 1.0], [31.491667, 65.629722, 1.0], [31.506337, 65.421682, 1.0], [31.508707, 62.700645, 1.0], [31.516754, 64.11309, 1.0], [31.517771, 64.114227, 1.0], [31.517962, 64.11378, 1.0], [31.5343, 64.250253, 1.0], [31.544476, 65.484566, 2.0], [31.550039, 65.45263, 4.0], [31.585831, 67.028191, 1.0], [31.587415, 64.373355, 1.0], [31.587778, 65.690278, 1.0], [31.60063, 64.369652, 10.0], [31.607109, 65.634674, 1.0], [31.617
# %%
coordinates = taliban_attack5.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
coordinates['normalize_count'] = (
    coordinates['incident_count'] - coordinates['incident_count'].min()
) / (
    coordinates['incident_count'].max() - coordinates['incident_count'].min()
)
heatmap_data = coordinates[['latitude', 'longitude', 'incident_count']].values.tolist()
taliban_attack_5 = folium.Map(location=[35, 70],  zoom_start=6,tiles='CartoDB Positron'  )
HeatMap(heatmap_data, radius=15, blur=15, max_zoom=10).add_to(taliban_attack_5)

for i, row in coordinates.iterrows():
    if row['incident_count'] > 1: 
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"Incidents: {row['incident_count']}",
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(taliban_attack_5)

taliban_attack_5.save('taliban_attack_5.html')
taliban_attack_5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bf10a9090691af4e876b51c6e78481c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bf10a9090691af4e876b51c6e78481c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0bf10a9090691af4e876b51c6e78481c = L.map(
#                 &quot;map_0bf10a9090691af4e876b51c6e78481c&quot;,
#                 {
#                     center: [35.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_542587e1240c3d79035309c3748ceb49 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_542587e1240c3d79035309c3748ceb49.addTo(map_0bf10a9090691af4e876b51c6e78481c);
#
#
#             var heat_map_76f80d45d720f5e3bee6108c59ce9bda = L.heatLayer(
#                 [[30.550198, 63.78606, 1.0], [31.139357, 65.76095, 1.0], [31.14202, 66.47649, 1.0], [31.305401, 64.2593, 1.0], [31.306599, 64.260358, 1.0], [31.389315, 64.315166, 1.0], [31.467463, 64.092445, 2.0], [31.467506, 65.25663, 1.0], [31.550039, 65.45263, 1.0], [31.61158, 65.699905, 1.0], [31.617667, 65.675942, 2.0], [31.627475, 65.564604, 1.0], [31.631083, 65.742226, 3.0], [31.637821, 64.237801, 1.0], [31.64, 64.24, 1.0], [31.80262, 66.324715, 1.0], [31.823984, 67.775917, 1.0], [31.825871, 64.576431, 2.0], [32.073333, 64.833889, 1.0], [32.100204, 66.901016, 1.0], [32.109447, 61.883274, 1.0], [32.191878, 67.189449, 1.0], [32.230825, 62.920592, 2.0], [32.241694, 62.947807, 2.0], [32.264539, 68.524715, 1.0], [32.302668, 65.079098, 1.0], [32.353991, 64.782591, 1.0], [32.37001, 62.128456, 4.0], [32.389052, 66.054439, 1.0], [32.480918, 62.028239, 1.0], [32.495328, 62.262663, 2.0], [32.509722, 68.855833, 1.0], [32.519241, 67.416481, 1.0], [32.625149, 62.479768, 2.0], [32.677851, 61.981391, 3.0], [32.747617, 67.60778, 1.0], [32.82, 67.769167, 1.0], [33.109734, 68.302658, 1.0], [33.125278, 67.9825, 2.0], [33.193665, 68.102002, 3.0], [33.279501, 69.598588, 1.0], [33.300747, 69.884109, 1.0], [33.30563,